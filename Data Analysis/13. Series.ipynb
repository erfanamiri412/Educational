# %%
import pandas as pd

# %%
d = pd.Series([10, 20, 30, 40, 50], index = ['Ali', 'Reza', 'Mamaly', 'Hamid', 'Bahram'], name = 'mySeries')
d
# Out:
# Ali       10
# Reza      20
# Mamaly    30
# Hamid     40
# Bahram    50
# Name: mySeries, dtype: int64

# %%
d = pd.Series({'Ali':10, 'Reza':20, 'Mamaly':30, 'Hamid':40, 'Bahram':50})
d
# Out:
# Ali       10
# Reza      20
# Mamaly    30
# Hamid     40
# Bahram    50
# dtype: int64

# %%
d.to_dict()
# Out:
# {'ali': 10, 'reza': 20, 'mamaly': 30, 'hamid': 40, 'hamed': 50}
