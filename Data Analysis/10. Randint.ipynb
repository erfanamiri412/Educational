# %%
import numpy as np

# %%
arr = np.random.randint(1, 100, size = (10, 10))
arr
# Out:
# array([[47, 96, 55, 62, 75, 50, 70, 14, 27, 62],
#        [69, 21, 65, 56, 11, 32, 24, 20, 92, 46],
#        [28, 60, 91, 17, 20, 15, 96, 58,  3, 74],
#        [28, 50, 11,  9, 14, 89, 18, 57, 70, 11],
#        [13, 75, 30, 81, 24, 87, 61, 76, 26, 39],
#        [98, 15, 83, 73, 79, 48, 55, 40, 80, 74],
#        [92, 80, 34, 75, 64, 96, 59, 41, 68, 58],
#        [20, 20,  3, 82, 71,  1, 71, 38, 32, 99],
#        [86, 80, 53, 61, 11, 97, 13, 37, 73, 39],
#        [40, 50, 55, 95, 12, 84, 84, 40, 66, 78]], dtype=int32)

# %%
arr2 = np.random.randint(1, 100, size = (3, 3))
arr2
# Out:
# array([[ 3, 45, 72],
#        [97, 17, 85],
#        [70, 37, 45]], dtype=int32)
