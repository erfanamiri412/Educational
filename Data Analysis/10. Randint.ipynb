# %%
import numpy as np

# %%
arr = np.random.randint(1, 100, size = (10, 10))
arr
# Out:
# array([[87, 24, 21, 48, 96, 77,  5, 21, 30, 93],
#        [22, 31,  3, 77, 45, 30, 81, 75, 64, 14],
#        [13, 88, 82, 99, 76, 51, 33, 29, 22, 67],
#        [25, 93, 96,  9, 34, 50, 96, 69, 83, 21],
#        [93, 23,  5, 74, 74, 24, 13, 99, 55, 47],
#        [52, 79, 64, 66, 25,  9, 43, 55,  9, 95],
#        [ 7, 45, 11, 88, 72, 34, 42, 23, 34, 52],
#        [65, 94,  7, 69, 55, 90, 13, 91, 64, 18],
#        [ 2, 73, 17, 95, 46, 85, 24, 49, 22, 42],
#        [30, 95, 33, 15, 89, 40,  2, 20, 56, 15]], dtype=int32)

# %%
arr2 = np.random.randint(1, 100, size = (3, 3))
arr2
# Out:
# array([[ 3, 45, 72],
#        [97, 17, 85],
#        [70, 37, 45]], dtype=int32)
