# %%
import numpy as np

# %%
arr = np.linspace(10, 20, 3)
arr2 = np.ones_like(arr)
arr, arr2
# Out:
# (array([10., 15., 20.]), array([1., 1., 1.]))

# %%
arr = np.linspace(10, 20, 3)
arr2 = np.zeros_like(arr)
arr, arr2
# Out:
# (array([10., 15., 20.]), array([0., 0., 0.]))
