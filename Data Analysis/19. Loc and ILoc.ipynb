# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/refs/heads/master/titanic.csv')

# %%
df.loc[155, 'Name']
# Out:
# 'Williams, Mr. Charles Duane'

# %%
df.loc[150:155, ['Name', 'Sex']]
# Out:
#                                   Name     Sex
# 150         Bateman, Rev. Robert James    male
# 151  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                   Meo, Mr. Alfonzo    male
# 153    van Billiard, Mr. Austin Blyler    male
# 154              Olsen, Mr. Ole Martin    male
# 155        Williams, Mr. Charles Duane    male

# %%
df.iloc[155, 3]
# Out:
# 'Williams, Mr. Charles Duane'

# %%
df.iloc[-3:, 3]
# Out:
# 153    van Billiard, Mr. Austin Blyler
# 154              Olsen, Mr. Ole Martin
# 155        Williams, Mr. Charles Duane
# Name: Name, dtype: object

# %%
df[['Name', 'Sex']].iloc[150:155]
# Out:
#                                   Name     Sex
# 150         Bateman, Rev. Robert James    male
# 151  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                   Meo, Mr. Alfonzo    male
# 153    van Billiard, Mr. Austin Blyler    male
# 154              Olsen, Mr. Ole Martin    male
