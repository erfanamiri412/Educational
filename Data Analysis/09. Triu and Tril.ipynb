# %%
import numpy as np

# %%
arr = np.ones((3,3))
arr2 = np.triu(arr)
arr2
# Out:
# array([[1., 1., 1.],
#        [0., 1., 1.],
#        [0., 0., 1.]])

# %%
arr = np.ones((3,3))
arr2 = np.tril(arr)
arr2
# Out:
# array([[1., 0., 0.],
#        [1., 1., 0.],
#        [1., 1., 1.]])
