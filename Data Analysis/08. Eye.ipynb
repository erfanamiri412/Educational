# %%
import numpy as np

# %%
arr = np.eye(3, 3)
arr
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
arr = np.eye(3, 3, k=1)
arr
# Out:
# array([[0., 1., 0.],
#        [0., 0., 1.],
#        [0., 0., 0.]])

# %%
arr = np.eye(3,3, k=2)
arr
# Out:
# array([[0., 0., 1.],
#        [0., 0., 0.],
#        [0., 0., 0.]])
