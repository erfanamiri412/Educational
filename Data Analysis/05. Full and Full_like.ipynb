# %%
import numpy as np

# %%
arr = np.full((3, 3), fill_value = 10)
arr
# Out:
# array([[10, 10, 10],
#        [10, 10, 10],
#        [10, 10, 10]])

# %%
arr2 = np.full_like(arr, fill_value = 10)
arr2
# Out:
# array([[10, 10, 10],
#        [10, 10, 10],
#        [10, 10, 10]])
